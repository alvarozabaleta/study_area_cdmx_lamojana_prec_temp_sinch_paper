# %%
from ipyleaflet import Map, Marker, MarkerCluster, Popup
from ipywidgets import HTML

# %%
center = (14.021153, -89.983865)

coordinates_mcs1 = (19.4125, -99.2017)
coordinates_mcs2 = (19.3033, -99.1481)
coordinates_mcs3 = (19.3339, -99.1322)
coordinates_mcs4 = (19.2969, -99.1822)
coordinates_mcs5 = (19.4767, -99.0914)
coordinates_mcs6 = (19.1344, -99.1731)
coordinates_mcs7 = (19.1906, -99.0219)
coordinates_mcs8 = (19.3953, -99.0978)
coordinates_mcs9 = (19.4292, -99.0528)
coordinates_mcs10 = (19.1967, -99.1286)
coordinates_mcs11 = (19.4653, -99.0792)
coordinates_mcs12 = (19.1789, -99.0028)
coordinates_mcs13 = (19.4036, -99.1961)
coordinates_mcs14 = (19.2628, -99.0036)

coordinates_lms1 = (9.28194, -74.84528)
coordinates_lms2 = (8.29519, -75.16450)
coordinates_lms3 = (8.18078, -75.63228)
coordinates_lms4 = (8.74086, -75.49883)
coordinates_lms5 = (8.54283, -74.63556)
coordinates_lms6 = (8.92075, -74.47425)
coordinates_lms7 = (8.39933, -75.58372)

marker_mc1 = Marker(location=coordinates_mcs1, title="MCS1", draggable=True)
marker_mc2 = Marker(location=coordinates_mcs2, title="MCS2", draggable=True)
marker_mc3 = Marker(location=coordinates_mcs3, title="MCS3", draggable=True)
marker_mc4 = Marker(location=coordinates_mcs4, title="MCS4", draggable=True)
marker_mc5 = Marker(location=coordinates_mcs5, title="MCS5", draggable=True)
marker_mc6 = Marker(location=coordinates_mcs6, title="MCS6", draggable=True)
marker_mc7 = Marker(location=coordinates_mcs7, title="MCS7", draggable=True)
marker_mc8 = Marker(location=coordinates_mcs8, title="MCS8", draggable=True)
marker_mc9 = Marker(location=coordinates_mcs9, title="MCS9", draggable=True)
marker_mc10 = Marker(location=coordinates_mcs10, title="MCS10", draggable=True)
marker_mc11 = Marker(location=coordinates_mcs11, title="MCS11", draggable=True)
marker_mc12 = Marker(location=coordinates_mcs12, title="MCS12", draggable=True)
marker_mc13 = Marker(location=coordinates_mcs13, title="MCS13", draggable=True)
marker_mc14 = Marker(location=coordinates_mcs14, title="MCS14", draggable=True)

marker_lms1 = Marker(location=coordinates_lms1, title="LMS1", draggable=True)
marker_lms2 = Marker(location=coordinates_lms2, title="LMS2", draggable=True)
marker_lms3 = Marker(location=coordinates_lms3, title="LMS3", draggable=True)
marker_lms4 = Marker(location=coordinates_lms4, title="LMS4", draggable=True)
marker_lms5 = Marker(location=coordinates_lms5, title="LMS5", draggable=True)
marker_lms6 = Marker(location=coordinates_lms6, title="LMS6", draggable=True)
marker_lms7 = Marker(location=coordinates_lms7, title="LMS7", draggable=True)

coordinates = [coordinates_mcs1, coordinates_mcs2, coordinates_mcs3, coordinates_mcs4, coordinates_mcs5, coordinates_mcs6, coordinates_mcs7, coordinates_mcs8, coordinates_mcs9, coordinates_mcs10,
               coordinates_mcs11, coordinates_mcs12, coordinates_mcs13, coordinates_mcs14, coordinates_lms1, coordinates_lms2, coordinates_lms3, coordinates_lms4, coordinates_lms5, coordinates_lms6, coordinates_lms7]

pops = ["MCS1", "MCS2", "MCS3", "MCS4", "MCS5", "MCS6", "MCS7", "MCS8", "MCS9", "MCS10", "MCS11", "MCS12", "MCS13", "MCS14", "LMS1", "LMS2", "LMS3", "LMS4", "LMS5", "LMS6", "LMS7"]

markers=(marker_mc1, marker_mc2, marker_mc3, marker_mc4, marker_mc5, marker_mc6, marker_mc7, marker_mc8, marker_mc9, marker_mc10, marker_mc11, marker_mc12, marker_mc13, marker_mc14,
                               marker_lms1, marker_lms2, marker_lms3, marker_lms4, marker_lms5, marker_lms6, marker_lms7)
m = Map(center=center, zoom=3)

marker_cluster = MarkerCluster(markers=markers)

m.add_layer(marker_cluster)

for i, marker in enumerate(markers):
  message = HTML()
  message.value = pops[i]
  marker.popup = message

m
# Out:
# Map(center=[14.021153, -89.983865], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…
